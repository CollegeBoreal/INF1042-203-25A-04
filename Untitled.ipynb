# %%
300155504
# Out:
# 300155504

# %%
# %run main.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\Documents\INF1042\8.OOP\300155504\main.py:10
#       1 # Signature : BadrEddine Barragoub - 300155504
#       3 """
#       4 Fichier : main.py
#       5 Description : Programme de test pour la classe Carré.
#       6 Auteur : 300155504
#       7 Date : 2025-12-10
#       8 """
# ---> 10 from carre import Carre
#      12 def main():
#      13     carre1 = Carre(4)
#
# ModuleNotFoundError: No module named 'carre'

# %%
# %run main.py
# Out:
# Figure : Carré, côté=4, aire=16
# Figure : Carré, côté=7, aire=49

# %%
300155504

# %%
# %run main.py

# %%
# %run main.py
