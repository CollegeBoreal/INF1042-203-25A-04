# %% [markdown]
# $g(n)= 2n$

# %%
def g(n):
    return 2*n

for i in range(1, 11):
    print(i, "→", g(i))
# Out:
# 1 → 2
# 2 → 4
# 3 → 6
# 4 → 8
# 5 → 10
# 6 → 12
# 7 → 14
# 8 → 16
# 9 → 18
# 10 → 20
