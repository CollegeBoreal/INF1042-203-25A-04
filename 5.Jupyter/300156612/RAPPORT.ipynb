# %%
# demander le nom dutilisateur puis luis dire bonjour

# %%
nom = input ("comment tu t'appele ?")
# Out:
# comment tu t'appele ? ferhat

# %%
print ("bonjour" + nom + "! Bienvenue dans mon programme python")
# Out:
# bonjourferhat! Bienvenue dans mon programme python
