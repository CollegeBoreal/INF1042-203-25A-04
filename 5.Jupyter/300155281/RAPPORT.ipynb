# %% [markdown]
# # 🌟 Rapport d'Exploration Aléatoire 🌟
#
# Ce rapport présente un exemple simple de génération de données aléatoires et de visualisation dans un notebook Jupyter.
#
# Nous allons voir :
# 1. Des mots et nombres aléatoires
# 2. Un graphique aléatoire
# 3. Une citation aléatoire

# %%
# Import des bibliothèques nécessaires
import random
import matplotlib.pyplot as plt
import numpy as np

# --------------------------
# 1️⃣ Mot et chiffre aléatoire
# --------------------------
mots = ["Python", "Git", "Data", "Jupyter", "Machine Learning", "AI", "Notebook"]
mot_aleatoire = random.choice(mots)
chiffre_aleatoire = random.randint(1, 100)

print(f"Mot aléatoire : {mot_aleatoire}")
print(f"Chiffre aléatoire : {chiffre_aleatoire}")
# Out:
# Mot aléatoire : AI
# Chiffre aléatoire : 84
