# %%
# %run main.py
# Out:
# Figure: Carré, côté=4, aire=16
# Figure: Cercle, rayon=3, aire=28.27
# Figure: Triangle, base=5, hauteur=2, aire=5.0
# Figure: Trapèze, base1=6, base2=4, hauteur=3, aire=15.0
