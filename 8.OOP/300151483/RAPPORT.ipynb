# %% [markdown]
# # 🧮 Étude : Figures Géométriques — Aires et Visualisations
#
# | Nom | Arnold |
# | --- | ------- |
# | 🆔  | 300151483 |
#
#
# Ce notebook démontre l’utilisation d’une hiérarchie de classes Python :
#
# - `Figure` (classe de base)
# - `Carre`
# - `Cercle`
#
# Puis l'affichage graphique grâce à :
#
# - **matplotlib 3.9.2**
# - **numpy 2.1.3**

# %%
from carre import Carre
from cercle import Cercle
from triangle import Triangle
from trapeze import Trapeze

c1 = Carre(4)
c2 = Cercle(3)
t1 = Triangle(5, 2)
tr1 = Trapeze(6, 4, 3)

for f in [c1, c2, t1, tr1]:
    print(f.afficher_info())
    f.dessiner()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from carre import Carre
#       2 from cercle import Cercle
# ----> 3 from triangle import Triangle
#       4 from trapeze import Trapeze
#       6 c1 = Carre(4)
#
# ModuleNotFoundError: No module named 'triangle'

# %% [markdown]
# from carre import Carre
# from cercle import Cercle
#
# c1 = Carre(4)
# c2 = Cercle(3)
