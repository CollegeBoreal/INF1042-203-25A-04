# %% [markdown]
# # 🧮 Étude : Figures Géométriques — Aires et Visualisations
#
# |     |                           |
# | --- | ------------------------- |
# | Nom | Noureddine Boussekine                |
# | 🆔  | 300152315                |

# %% [markdown]
# ## ▶️ Importer les classes

# %%
from Carre import Carre
from Cercle import Cercle
from Triangle import Triangle


c1 = Carre(4)
c2 = Cercle(3)
t1 = Triangle(6,4)

print(c1.afficher_info())
print(c2.afficher_info())
print(t1.afficher_info())
# Out:
# Figure : Carré, côté=4, aire=16
# Figure : Cercle, rayon=3, aire=28.27
# Figure : Triangle, base=6, hauteur=4, aire=12.0

# %% [markdown]
# ## 🎨 Import pour affichage graphique

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 🟦 Afficher Carré

# %%
def afficher_carre(carre: Carre):
    x = [0, carre.cote, carre.cote, 0, 0]
    y = [0, 0, carre.cote, carre.cote, 0]
    plt.figure(figsize=(5,5))
    plt.plot(x,y)
    plt.fill(x,y,alpha=0.3)
    plt.title(f"Carré — côté={carre.cote}, aire={carre.aire()}")
    plt.axis('equal')
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## ⚪ Afficher Cercle

# %%
def afficher_cercle(cercle: Cercle):
    theta = np.linspace(0,2*np.pi,300)
    x = cercle.rayon * np.cos(theta)
    y = cercle.rayon * np.sin(theta)
    plt.figure(figsize=(5,5))
    plt.plot(x,y)
    plt.fill(x,y,alpha=0.3)
    plt.title(f"Cercle — rayon={cercle.rayon}, aire={cercle.aire():.2f}")
    plt.axis('equal')
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## 🔺 Afficher Triangle

# %%
def afficher_triangle(triangle: Triangle):
    x = [0, triangle.base, triangle.base/2, 0]
    y = [0, 0, triangle.hauteur, 0]
    plt.figure(figsize=(5,5))
    plt.plot(x,y,marker='o')
    plt.fill(x,y,alpha=0.3)
    plt.title(f"Triangle — base={triangle.base}, hauteur={triangle.hauteur}, aire={triangle.aire():.2f}")
    plt.axis('equal')
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## 🖼️ Affichage final

# %%
afficher_carre(c1)
afficher_cercle(c2)
afficher_triangle(t1)
