# %% [markdown]
# # 🧮 Étude : Figures Géométriques — Aires et Visualisations
#
# |     |                     |
# | --- | ------------------- |
# | Nom | Lyes hamed |
# | 🆔  | 300158486           |
#
# Ce notebook démontre l’utilisation d’une hiérarchie de classes Python :
#
# - `Figure` (classe de base)
# - `Carre`
# - `Cercle`
# - `Losange`
#
# Puis l'affichage graphique grâce à :
#
# - **matplotlib 3.9.2**
# - **numpy 2.1.3**
#
# Nous allons :
# 1. définir les classes dans le notebook
# 2. créer un carré et un cercle
# 3. tracer les figures graphiquement

# %%
from carre import Carre
from cercle import Cercle
from losange import Losange
c1 = Carre(4)
c2 = Cercle(3)
c3 = Losange(2)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# def afficher_carre(carre):
#     cote = carre.cote
#     x = [0, cote, cote, 0, 0]
#     y = [0, 0, cote, cote, 0]
#
#     plt.figure(figsize=(5, 5))
#     plt.plot(x, y)
#     plt.fill(x, y, alpha=0.3)
#     plt.title(f"Carré — côté={cote}, aire={carre.aire()}")
#     plt.axis("equal")
#     plt.grid(True)
#     plt.show()

# %% [markdown]
# def afficher_cercle(cercle):
#     r = cercle.rayon
#     theta = np.linspace(0, 2*np.pi, 300)
#
#     x = r * np.cos(theta)
#     y = r * np.sin(theta)
#
#     plt.figure(figsize=(5, 5))
#     plt.plot(x, y)
#     plt.fill(x, y, alpha=0.3)
#     plt.title(f"Cercle — rayon={r}, aire={cercle.aire():.2f}")
#     plt.axis("equal")
#     plt.grid(True)
#     plt.show()

# %%
def afficher_losange(losange):
    d1 = losange.d1
    d2 = losange.d2

    # Points du losange centré (haut, droite, bas, gauche, retour haut)
    x = [0,  d2/2,  0, -d2/2, 0]
    y = [d1/2, 0, -d1/2, 0,  d1/2]

    plt.figure(figsize=(5, 5))
    plt.plot(x, y, linewidth=2)
    plt.fill(x, y, alpha=0.3)
    plt.title(f"Losange — d1={d1}, d2={d2}, aire={losange.aire()}")
    plt.axis("equal")
    plt.grid(True)
    plt.show()

# %%
afficher_carre(c1)
afficher_cercle(c2)
afficher_losange(c3)
