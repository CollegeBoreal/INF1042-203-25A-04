# %% [raw]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "id": "af1a3a2c",
#    "metadata": {},
#    "source": [
#     "Variables en Python — Rapport\n",
#     "\n",
#     "Nom : Walid lahsaien\n",
#     "ID Boréal : 300156615\n",
#     "\n",
#     "Ce notebook présente trois sections :\n",
#     "1. Le module embellisseur et la fonction f\n",
#     "2. Le module moyenne (moyenne algébrique et géométrique)\n",
#     "3. Les ensembles (set) et la compréhension"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "2c642b2e",
#    "metadata": {},
#    "source": [
#     "## 1️⃣ Module embellisseur\n",
#     "\n",
#     "Cette section montre comment la fonction f traite différents types de variables.\n",
#     "Elle illustre le polymorphisme de Python : une même fonction peut gérer plusieurs types de données (entiers, flottants, chaînes, listes, tuples, dictionnaires, etc.)."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "id": "f0492b77",
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "from embellisseur import f\n",
#     "\n",
#     "exemples = [\n",
#     "    10,\n",
#     "    2.718,\n",
#     "    \"hello\",\n",
#     "    [7, 8, 9],\n",
#     "    (10, 20, 30),\n",
#     "    {\"x\": 1, \"y\": 2}\n",
#     "]\n",
#     "\n",
#     "for e in exemples:\n",
#     "    print(f\"\\n--- f({e}) ---\")\n",
#     "    resultat = f(e)\n",
#     "    for k, v in resultat.items():\n",
#     "        print(f\"{k:12} -> {v}\")"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "505065d1",
#    "metadata": {},
#    "source": [
#     "## 2️⃣ Moyenne algébrique et géométrique\n",
#     "\n",
#     "Le module moyenne contient deux fonctions :\n",
#     "- `algebrique(L)`\n",
#     "- `geometrique(L)`\n",
#     "\n",
#     "On applique ces fonctions à une liste de valeurs pour comparer les résultats."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "id": "fc76cc4e",
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "from moyenne import algebrique, geometrique\n",
#     "\n",
#     "L = [2, 4.5, 6, 8, 10]\n",
#     "\n",
#     "print(\"La moyenne algébrique est :\", algebrique(L))\n",
#     "print(\"La moyenne géométrique est :\", geometrique(L))"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "28595985",
#    "metadata": {},
#    "source": [
#     "## 3️⃣ Ensembles (set) et compréhension\n",
#     "\n",
#     "On construit un ensemble S de couples (k, x) où :\n",
#     "- k provient de K = ['A', 'B', 'C']\n",
#     "- x provient de X = [1, 2, 3, 4, 5, 6]\n",
#     "- x satisfait P(x) (être pair)\n"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "id": "a3482e49",
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "K = ['A', 'B', 'C']\n",
#     "X = [1, 2, 3, 4, 5, 6]\n",
#     "\n",
#     "def P(x):\n",
#     "    return x % 2 == 0\n",
#     "\n",
#     "S = {(k, x) for k in K for x in X if P(x)}\n",
#     "print(\"Ensemble des couples filtrés :\", S)\n",
#     "\n",
#     "x_values = [x for (_, x) in S]\n",
#     "moyenne = algebrique(x_values) if x_values else 0\n",
#     "\n",
#     "print(\"Moyenne algébrique des x filtrés :\", moyenne)"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "90083e93",
#    "metadata": {},
#    "source": [
#     "## Conclusion\n",
#     "\n",
#     "- Une fonction peut gérer plusieurs types de données en Python.\n",
#     "- Les deux moyennes illustrent la réutilisation de fonctions mathématiques.\n",
#     "- Les ensembles et les comprehensions permettent de filtrer et combiner des données efficacement."
#    ]
#   }
#  ],
#  "metadata": {},
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
