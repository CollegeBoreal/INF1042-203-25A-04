# %% [markdown]
# # 🍂 RAPPORT : Analyse de Code Python (Variables, Moyennes, Ensembles)
#
# <table>
#   <tr>
#     <td><strong>Nom</strong></td>
#     <td>WALID LAHSAIEN</td>
#   </tr>
#   <tr>
#     <td><strong>🆔</strong></td>
#     <td>300156615</td>
#   </tr>
# </table>
#
# ---
#
# ## 🐍 Leçon : Les variables en Python
# ### 🎯 Qu’est-ce qu’une variable ?
# Une variable est un nom qui sert à stocker une valeur dans la mémoire de l’ordinateur.
# Elle agit comme une **boîte étiquetée** contenant une information.
#
# ```python
# nom = "Alice"
# age = 25
# ```
#
# ---
#
# ## 🧠 Règles pour nommer une variable
#
# ✔ Commence par une lettre ou un `_`
# ✔ Pas d’espace
# ✔ Ne commence pas par un chiffre
# ✔ Sensible à la casse (`age` ≠ `Age`)
#
# ---
#
# ## 🔢 Types de valeurs
#
# | Exemple | Type |
# |--------|------|
# | `x = 10` | int |
# | `x = 3.14` | float |
# | `"Boréal"` | str |
# | `True` | bool |
#
# ---
#
# ## 🔁 Modifier une variable
#
# ```python
# note = 80
# note = note + 5
# ```
#
# ---
#
# ## 📦 Affectation multiple
#
# ```python
# a, b, c = 1, 2, 3
# ```
#
# ---
#
# ## 🧹 Supprimer une variable
#
# ```python
# del a
# ```
#
# ---
#
# # 🧩 1️⃣ Module `embellisseur` — Fonction f
#
# Cette section montre comment la fonction **f** réagit à plusieurs types : entier, float, chaîne, liste, tuple, dictionnaire.
# Cela illustre le **polymorphisme**.
#
# ```python
# from embellisseur import f
#
# exemples = [
#     10,
#     2.718,
#     "hello",
#     [7, 8, 9],
#     (10, 20, 30),
#     {"x": 1, "y": 2}
# ]
#
# for e in exemples:
#     print(f"\n--- f({e}) ---")
#     resultat = f(e)
#     for k, v in resultat.items():
#         print(f"{k:12} -> {v}")
# ```
#
# ---
#
# # 2️⃣ Moyenne algébrique & géométrique
#
# ### ▪ Moyenne algébrique
# \[
# \bar{x} = \frac{\sum x_i}{n}
# \]
#
# ### ▪ Moyenne géométrique
# \[
# G = \sqrt[n]{\prod x_i}
# \]
#
# ```python
# from moyenne import algebrique, geometrique
#
# print("La moyenne algébrique est :", algebrique([2, 4.5, 6, 8, 10]))
# print("La moyenne géométrique est :", geometrique([2, 4.5, 6, 8, 10]))
# ```
#
# ---
#
# # 3️⃣ Ensembles (set) et compréhension
#
# On construit un ensemble :
#
# \[
# \{(k,x)\ |\ k\in K \land x\in X \land P(x)\}
# \]
#
# Avec :
# - `K = ['A', 'B', 'C']`
# - `X = [1, 2, 3, 4, 5, 6]`
# - `P(x)` = nombre pair
#
# ```python
# K = ['A', 'B', 'C']
# X = [1, 2, 3, 4, 5, 6]
#
# def P(x):
#     return x % 2 == 0
#
# S = {(k, x) for k in K for x in X if P(x)}
# print("Ensemble des couples filtrés :", S)
#
# x_values = [x for (_, x) in S]
# if x_values:
#     moyenne = algebrique(x_values)
# else:
#     moyenne = 0
#
# print("Moyenne algébrique des x filtrés :", moyenne)
# ```
#
# ---
#
# # 🧠 Conclusion
#
# Ce rapport montre que :
#
# - Une même fonction peut traiter plusieurs types grâce au **typage dynamique** de Python.
# - Les fonctions `algebrique` et `geometrique` sont réutilisables dans plusieurs contextes.
# - Les ensembles et compréhensions permettent de filtrer et combiner des données de façon simple et efficace.
#
# ---
