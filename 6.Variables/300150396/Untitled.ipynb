# %%
import nbformat as nbf

nb = nbf.v4.new_notebook()
cells = []

# Exemple de première cellule Markdown
cells.append(nbf.v4.new_markdown_cell("# 🪐 RAPPORT : Analyse de Code Python (Variables, Moyennes, Ensembles)"))

# Ajouter une cellule Code exemple
cells.append(nbf.v4.new_code_cell("print('Hello Jupyter !')"))

nb['cells'] = cells

# Enregistrer dans le dossier courant
with open("RAPPORT.ipynb", 'w', encoding='utf-8') as f:
    nbf.write(nb, f)

print("Notebook créé : RAPPORT.ipynb")
