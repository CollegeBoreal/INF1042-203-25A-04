# %% [markdown]
#
# # 🪐 RAPPORT : Analyse de Code Python (Variables, Moyennes, Ensembles)
#
# |     |                     |
# | --- | ------------------- |
# | Nom | arnauld |
# | 🆔  | 300151483           |
#
#
# Ce notebook présente trois sections :
# 1. Le module `embellisseur` et la fonction `f`
# 2. Le module `moyenne` (moyenne algébrique et géométrique)
# 3. Les ensembles (`set`) et la compréhension

# %%
from embellisseur import f

exemples = [
    10,
    2.718,
    "hello",
    [7, 8, 9],
    (10, 20, 30),
    {"x": 1, "y": 2}
]

for e in exemples:
    print(f"\n--- f({e}) ---")
    resultat = f(e)
    for k, v in resultat.items():
        print(f"{k:12} -> {v}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from embellisseur import f
#       3 exemples = [
#       4     10,
#       5     2.718,
#    (...)      9     {"x": 1, "y": 2}
#      10 ]
#      12 for e in exemples:
#
# ModuleNotFoundError: No module named 'embellisseur'
