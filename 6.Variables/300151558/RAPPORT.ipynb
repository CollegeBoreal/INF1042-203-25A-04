# %% [markdown]
# # 🪐 RAPPORT : Analyse de Code Python
# Variables — Moyennes — Ensembles
#
# | Élément | Information |
# |--------|-------------|
# | Nom    | Hind Chili |
# | 🆔     | 300151558   |

# %% [markdown]
# ## 1️⃣ Analyse du module `embellisseur`
#
# Cette section teste la fonction `f` avec différents types de données.
# Elle permet d’observer comment Python traite le polymorphisme.

# %%
from embellisseur import f

exemples = [
    10,
    2.718,
    "hello",
    [7, 8, 9],
    (10, 20, 30),
    {"x": 1, "y": 2}
]

for e in exemples:
    print(f"\n--- f({e}) ---")
    resultat = f(e)
    for k, v in resultat.items():
        print(f"{k:12} -> {v}")
# Out:
# --- f(10) ---
# binaire      -> 0b1010
# hexadécimal  -> 0xa
# int          -> 10
# float        -> 10.0
# str          -> 10
#
# --- f(2.718) ---
# float        -> 2.718
# int          -> 2
# str          -> 2.718
#
# --- f(hello) ---
# str          -> hello
# list         -> ['h', 'e', 'l', 'l', 'o']
# tuple        -> ('h', 'e', 'l', 'l', 'o')
#
# --- f([7, 8, 9]) ---
# list         -> [7, 8, 9]
# tuple        -> (7, 8, 9)
# array        -> array('i', [7, 8, 9])
# str          -> [7, 8, 9]
#
# --- f((10, 20, 30)) ---
# tuple        -> (10, 20, 30)
# list         -> [10, 20, 30]
# array        -> array('i', [10, 20, 30])
# str          -> (10, 20, 30)
#
# --- f({'x': 1, 'y': 2}) ---
# dict         -> {'x': 1, 'y': 2}
# list_clés    -> ['x', 'y']
# list_valeurs -> [1, 2]
# str          -> {'x': 1, 'y': 2}

# %% [markdown]
# ## 2️⃣ Calcul des Moyennes (Algébrique et Géométrique)
#
# Dans cette section, nous utilisons le module `moyenne` qui contient :
# - `algebrique(L)` : calcule la moyenne arithmétique
# - `geometrique(L)` : calcule la moyenne géométrique
#
# Nous allons les appliquer à une liste de valeurs numériques.

# %%
from moyenne import algebrique, geometrique

L = [2, 4.5, 6, 8, 10]

print("Moyenne algébrique :", algebrique(L))
print("Moyenne géométrique :", geometrique(L))
# Out:
# Moyenne algébrique : 6.1
# Moyenne géométrique : 5.3345372167932

# %% [markdown]
# ## 3️⃣ Ensembles (set) et Compréhensions
#
# Nous construisons un ensemble `S` de couples `(k, x)` où :
# - `k` provient de `K = ['A', 'B', 'C']`
# - `x` provient de `X = [1, 2, 3, 4, 5, 6]`
# - `x` satisfait une condition `P(x)` : être **pair**
#
# Ensuite, nous calculons la moyenne algébrique des valeurs retenues.

# %% [markdown]
# ## 🧠 Conclusion
#
# Ce rapport met en évidence plusieurs points importants :
#
# - Une même fonction (`f`) peut traiter plusieurs types de données (polymorphisme).
# - Les fonctions `algebrique` et `geometrique` permettent d'analyser des listes de valeurs.
# - Les ensembles (`set`) et les compréhensions offrent une manière concise et efficace de filtrer des données.
# - Python facilite énormément l’analyse et la manipulation de données grâce à sa flexibilité.
