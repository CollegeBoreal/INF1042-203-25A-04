# %% [markdown]
# # 🧮 Étude : Influence des boucles et de la récursion sur les algorithmes
#
# |     |                     |
# | --- | ------------------- |
# | Nom | Houssam Eddine RAchdi |
# | 🆔  | 300157440 |
#
# Ce rapport démontre comment les **algorithmes** sont influencés par la
# **programmation itérative** et la **programmation récursive** en Python.

# %% [markdown]
# ## 1️⃣ Factorielle
#
# ### 🔹 Formule mathématique
#
# $
# n! = \begin{cases}
# 1, & \text{si } n = 0 \\
# n \times (n - 1)!, & \text{si } n > 0
# \end{cases}
# $

# %%
def factorielle_iterative(n):
    resultat = 1
    for i in range(1, n + 1):
        resultat *= i
    return resultat

factorielle_iterative(5)
# Out:
# 120

# %%
def factorielle_recursive(n):
    if n == 0:
        return 1
    return n * factorielle_recursive(n - 1)

factorielle_recursive(5)
# Out:
# 120

# %%
from functools import reduce

def factorielle_comprehension(n):
    if n == 0:
        return 1
    return reduce(lambda x, y: x * y, [i for i in range(1, n + 1)])

factorielle_comprehension(5)
# Out:
# 120

# %% [markdown]
# ### 🧾 Synthèse – Factorielle
#
# Les trois méthodes donnent le même résultat.
#
# - Itérative : simple et efficace
# - Récursive : proche de la définition mathématique
# - Fonctionnelle : utilisation de `reduce` et compréhension de liste

# %%
def somme_while(n):
    i = 1
    s = 0
    while i <= n:
        s += i
        i += 1
    return s

somme_while(5)
# Out:
# 15

# %%
def somme_recursive(n):
    if n == 0:
        return 0
    return n + somme_recursive(n - 1)

somme_recursive(5)
# Out:
# 15

# %%
def fib_iter(n):
    a, b = 0, 1
    for _ in range(n):
        a, b = b, a + b
    return a

fib_iter(10)
# Out:
# 55

# %%
def fib_rec(n):
    if n <= 1:
        return n
    return fib_rec(n - 1) + fib_rec(n - 2)

fib_rec(10)
# Out:
# 55

# %% [markdown]
# ## 📘 Synthèse comparative
#
# | Algorithme | Complexité |
# |-----------|------------|
# | Factorielle | O(n) |
# | Somme | O(n) |
# | Fibonacci récursif | O(2^n) |
# | Fibonacci itératif | O(n) |

# %% [markdown]
# ## 🧠 Conclusion
#
# - Les boucles sont plus efficaces en mémoire
# - La récursion est plus intuitive mathématiquement
# - Le choix dépend de la lisibilité et de la performance
